# %% [markdown]
# Jeu de cartes

# %%
import random
import ModuleCarte as mc

if __name__ == "__main__":

    jeu = CJeuDeCartes()

    print("\nJeu original:")
    jeu.afficher()

    carte = jeu.battre()
    print("\nJeu mélangé:")
    jeu.afficher()

    carte_tirer = jeu.tirer()
    print(f"\nCarte tirée: {carte_tirer}")

    print("\nJeu après extraction:")
    jeu.afficher()
# Out:
# Jeu original:
# As de Coeur
# 2 de Coeur
# 3 de Coeur
# 4 de Coeur
# 5 de Coeur
# 6 de Coeur
# 7 de Coeur
# 8 de Coeur
# 9 de Coeur
# 10 de Coeur
# Valet de Coeur
# Dame de Coeur
# Roi de Coeur
# As de Carreau
# 2 de Carreau
# 3 de Carreau
# 4 de Carreau
# 5 de Carreau
# 6 de Carreau
# 7 de Carreau
# 8 de Carreau
# 9 de Carreau
# 10 de Carreau
# Valet de Carreau
# Dame de Carreau
# Roi de Carreau
# As de Pique
# 2 de Pique
# 3 de Pique
# 4 de Pique
# 5 de Pique
# 6 de Pique
# 7 de Pique
# 8 de Pique
# 9 de Pique
# 10 de Pique
# Valet de Pique
# Dame de Pique
# Roi de Pique
# As de Trèfle
# 2 de Trèfle
# 3 de Trèfle
# 4 de Trèfle
# 5 de Trèfle
# 6 de Trèfle
# 7 de Trèfle
# 8 de Trèfle
# 9 de Trèfle
# 10 de Trèfle
# Valet de Trèfle
# Dame de Trèfle
# Roi de Trèfle
#
# Jeu mélangé:
# 5 de Trèfle
# 7 de Carreau
# Dame de Trèfle
# 5 de Pique
# 9 de Trèfle
# 6 de Coeur
# Valet de Carreau
# 5 de Carreau
# 3 de Coeur
# 8 de Trèfle
# Dame de Coeur
# 4 de Carreau
# As de Pique
# 6 de Pique
# ...
